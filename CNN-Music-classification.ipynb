# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os, json, math, librosa

import IPython.display as ipd
import librosa.display

import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D

import sklearn.model_selection as sk

from sklearn.model_selection import train_test_split

# %%
MUSIC = 'D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/'
music_dataset = [] # File locations for each wav file 
genre_target = [] # 
for root, dirs, files in os.walk(MUSIC):
    for name in files:
        filename = os.path.join(root, name)
        if filename != '/data/genres_original/jazz/jazz.00054.wav':
            music_dataset.append(filename)
            genre_target.append(filename.split("/")[5])

# %%
DATASET_PATH = 'D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/'
JSON_PATH = "D:/etudes/cours/3eme Annee-Fay/DataMining/Data/data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

              # load audio file

                file_path = os.path.join(dirpath, f)
            
                if file_path != 'D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz/jazz.00054.wav':

                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                
                
                    # process all segments of audio file
                    for d in range(num_segments):

                        # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        # extract mfcc
                        mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)
# Out:
# Processing: blues
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00000.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00000.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00000.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00000.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00000.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00000.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00001.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00001.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00001.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00001.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00001.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00001.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00002.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00002.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00002.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00002.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00002.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00002.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00003.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00003.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00003.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00003.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00003.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00003.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00004.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00004.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00004.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00004.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00004.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00004.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00005.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00005.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00005.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00005.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00005.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00005.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00006.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00006.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00006.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00006.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00006.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00006.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00007.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00007.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00007.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00007.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00007.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00007.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00008.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00008.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00008.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00008.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00008.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00008.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00009.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00009.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00009.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00009.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00009.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00009.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00010.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00010.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00010.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00010.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00010.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00010.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00011.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00011.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00011.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00011.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00011.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00011.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00012.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00012.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00012.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00012.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00012.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00012.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00013.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00013.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00013.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00013.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00013.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00013.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00014.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00014.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00014.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00014.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00014.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00014.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00015.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00015.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00015.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00015.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00015.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00015.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00016.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00016.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00016.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00016.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00016.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00016.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00017.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00017.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00017.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00017.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00017.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00017.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00018.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00018.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00018.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00018.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00018.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00018.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00019.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00019.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00019.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00019.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00019.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00019.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00020.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00020.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00020.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00020.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00020.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00020.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00021.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00021.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00021.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00021.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00021.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00021.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00022.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00022.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00022.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00022.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00022.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00022.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00023.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00023.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00023.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00023.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00023.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00023.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00024.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00024.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00024.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00024.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00024.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00024.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00025.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00025.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00025.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00025.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00025.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00025.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00026.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00026.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00026.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00026.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00026.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00026.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00027.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00027.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00027.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00027.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00027.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00027.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00028.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00028.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00028.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00028.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00028.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00028.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00029.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00029.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00029.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00029.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00029.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00029.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00030.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00030.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00030.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00030.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00030.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00030.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00031.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00031.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00031.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00031.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00031.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00031.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00032.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00032.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00032.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00032.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00032.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00032.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00033.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00033.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00033.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00033.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00033.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00033.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00034.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00034.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00034.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00034.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00034.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00034.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00035.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00035.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00035.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00035.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00035.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00035.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00036.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00036.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00036.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00036.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00036.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00036.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00037.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00037.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00037.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00037.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00037.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00037.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.00038.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/blues\blues.
wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00043.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00043.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00043.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00043.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00044.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00044.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00044.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00044.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00044.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00044.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00045.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00045.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00045.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00045.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00045.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00045.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00046.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00046.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00046.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00046.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00046.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00046.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00047.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00047.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00047.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00047.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00047.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00047.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00048.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00048.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00048.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00048.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00048.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00048.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00049.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00049.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00049.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00049.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00049.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00049.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00050.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00050.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00050.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00050.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00050.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00050.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00051.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00051.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00051.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00051.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00051.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00051.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00052.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00052.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00052.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00052.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00052.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00052.wav, segment:6
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00053.wav, segment:1
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00053.wav, segment:2
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00053.wav, segment:3
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00053.wav, segment:4
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00053.wav, segment:5
# D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\jazz.00053.wav, segment:6
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     145     try:
# --> 146         with sf.SoundFile(path) as sf_desc:
#     147             sr_native = sf_desc.samplerate
#
# ~\anaconda3\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ~\anaconda3\lib\site-packages\soundfile.py in _open(self, file, mode_int, closefd)
#    1182             raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183         _error_check(_snd.sf_error(file_ptr),
#    1184                      "Error opening {0!r}: ".format(self.name))
#
# ~\anaconda3\lib\site-packages\soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening 'D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz\\jazz.00054.wav': Format not recognised.
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# <ipython-input-16-22b04097cc8b> in <module>
# ----> 1 save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)
#
# <ipython-input-15-51fa3f8f2993> in save_mfcc(dataset_path, json_path, num_mfcc, n_fft, hop_length, num_segments)
#      47                 if file_path != 'D:/etudes/cours/3eme Annee-Fay/DataMining/Data/genres_original/jazz/jazz.00054.wav':
#      48
# ---> 49                     signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
#      50
#      51
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     161         if isinstance(path, (str, pathlib.PurePath)):
#     162             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 163             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     164         else:
#     165             raise (exc)
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in __audioread_load(path, offset, duration, dtype)
#     185
#     186     y = []
# --> 187     with audioread.audio_open(path) as input_file:
#     188         sr_native = input_file.samplerate
#     189         n_channels = input_file.channels
#
# ~\anaconda3\lib\site-packages\audioread\__init__.py in audio_open(path, backends)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:

# %%
DATA_PATH = 'D:/etudes/cours/3eme Annee-Fay/DataMining/Data/data_10.json'


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    z = np.array(data['mapping'])
    return X, y, z
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    :return z : Mappings for data
    """

    # load data
    X, y, z = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test, z

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)
    
    # get mappings for target and predicted label
    target = z[y]
    predicted = z[predicted_index]

    print("Target: {}, Predicted label: {}".format(target, predicted))

# %%
# get train, validation, test splits
X_train, X_validation, X_test, y_train, y_validation, y_test, z = prepare_datasets(0.25, 0.2)

# create network
input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# train model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

# plot accuracy/error for training and validation
plot_history(history)

# evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 214, 11, 32)       320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 107, 6, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 107, 6, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 105, 4, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 2, 32)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 53, 2, 32)         128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 1, 32)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 26, 1, 32)         128
# _________________________________________________________________
# flatten (Flatten)            (None, 832)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                53312
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 68,042
# Trainable params: 67,850
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/30
# 113/113 [==============================] - 5s 40ms/step - loss: 2.8166 - accuracy: 0.1501 - val_loss: 1.9265 - val_accuracy: 0.3482
# Epoch 2/30
# 113/113 [==============================] - 4s 39ms/step - loss: 2.0348 - accuracy: 0.3355 - val_loss: 1.6219 - val_accuracy: 0.4271
# Epoch 3/30
# 113/113 [==============================] - 4s 40ms/step - loss: 1.7525 - accuracy: 0.4002 - val_loss: 1.4594 - val_accuracy: 0.4761
# Epoch 4/30
# 113/113 [==============================] - 5s 40ms/step - loss: 1.5273 - accuracy: 0.4652 - val_loss: 1.3600 - val_accuracy: 0.5239
# Epoch 5/30
# 113/113 [==============================] - 5s 40ms/step - loss: 1.4697 - accuracy: 0.4788 - val_loss: 1.2790 - val_accuracy: 0.5628
# Epoch 6/30
# 113/113 [==============================] - 5s 41ms/step - loss: 1.3837 - accuracy: 0.5104 - val_loss: 1.2277 - val_accuracy: 0.5717
# Epoch 7/30
# 113/113 [==============================] - 5s 41ms/step - loss: 1.2530 - accuracy: 0.5682 - val_loss: 1.1664 - val_accuracy: 0.5996
# Epoch 8/30
# 113/113 [==============================] - 5s 41ms/step - loss: 1.2522 - accuracy: 0.5615 - val_loss: 1.1458 - val_accuracy: 0.6073
# Epoch 9/30
# 113/113 [==============================] - 5s 42ms/step - loss: 1.1818 - accuracy: 0.5800 - val_loss: 1.1216 - val_accuracy: 0.5984
# Epoch 10/30
# 113/113 [==============================] - 5s 42ms/step - loss: 1.1126 - accuracy: 0.6020 - val_loss: 1.0769 - val_accuracy: 0.6251
# Epoch 11/30
# 113/113 [==============================] - 5s 43ms/step - loss: 1.0865 - accuracy: 0.6049 - val_loss: 1.0302 - val_accuracy: 0.6440
# Epoch 12/30
# 113/113 [==============================] - 5s 43ms/step - loss: 1.0404 - accuracy: 0.6239 - val_loss: 1.0358 - val_accuracy: 0.6385
# Epoch 13/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.9998 - accuracy: 0.6405 - val_loss: 1.0095 - val_accuracy: 0.6618
# Epoch 14/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.9562 - accuracy: 0.6706 - val_loss: 0.9955 - val_accuracy: 0.6496
# Epoch 15/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.9105 - accuracy: 0.6940 - val_loss: 0.9842 - val_accuracy: 0.6574
# Epoch 16/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.8658 - accuracy: 0.7066 - val_loss: 0.9756 - val_accuracy: 0.6830
# Epoch 17/30
# 113/113 [==============================] - 5s 44ms/step - loss: 0.8529 - accuracy: 0.6962 - val_loss: 0.9544 - val_accuracy: 0.6730
# Epoch 18/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.8327 - accuracy: 0.6988 - val_loss: 0.9341 - val_accuracy: 0.6830
# Epoch 19/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.8020 - accuracy: 0.7174 - val_loss: 0.9266 - val_accuracy: 0.6730
# Epoch 20/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.7630 - accuracy: 0.7288 - val_loss: 0.9147 - val_accuracy: 0.6785
# Epoch 21/30
# 113/113 [==============================] - 5s 43ms/step - loss: 0.7576 - accuracy: 0.7444 - val_loss: 0.9085 - val_accuracy: 0.6796
# Epoch 22/30
# 113/113 [==============================] - 5s 44ms/step - loss: 0.7298 - accuracy: 0.7590 - val_loss: 0.8903 - val_accuracy: 0.6874
# Epoch 23/30
# 113/113 [==============================] - 5s 46ms/step - loss: 0.6757 - accuracy: 0.7705 - val_loss: 0.8775 - val_accuracy: 0.7008
# Epoch 24/30
# 113/113 [==============================] - 5s 45ms/step - loss: 0.6824 - accuracy: 0.7610 - val_loss: 0.8984 - val_accuracy: 0.6852
# Epoch 25/30
# 113/113 [==============================] - 5s 45ms/step - loss: 0.6714 - accuracy: 0.7736 - val_loss: 0.8784 - val_accuracy: 0.7052
# Epoch 26/30
# 113/113 [==============================] - 5s 45ms/step - loss: 0.6312 - accuracy: 0.7783 - val_loss: 0.8820 - val_accuracy: 0.6963
# Epoch 27/30
# 113/113 [==============================] - 5s 44ms/step - loss: 0.6352 - accuracy: 0.7831 - val_loss: 0.8675 - val_accuracy: 0.6930
# Epoch 28/30
# 113/113 [==============================] - 5s 45ms/step - loss: 0.6152 - accuracy: 0.8004 - val_loss: 0.8574 - val_accuracy: 0.7075
# Epoch 29/30
# 113/113 [==============================] - 5s 45ms/step - loss: 0.5856 - accuracy: 0.8075 - val_loss: 0.8735 - val_accuracy: 0.7041
# Epoch 30/30
# 113/113 [==============================] - 5s 46ms/step - loss: 0.5645 - accuracy: 0.7986 - val_loss: 0.8845 - val_accuracy: 0.6908
# 47/47 - 0s - loss: 0.9272 - accuracy: 0.6802
#
# Test accuracy: 0.6802403330802917

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[10]
y_to_predict = y_test[10]

# predict sample
predict(model, X_to_predict, y_to_predict)
# Out:
# Target: jazz, Predicted label: ['rock']
